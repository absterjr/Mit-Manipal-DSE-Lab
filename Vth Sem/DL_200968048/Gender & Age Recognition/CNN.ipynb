# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
import glob
import cv2

import os
import keras
from keras.layers import *
from keras.models import *
from keras import backend as K

path = "../input/utkface-new/UTKFace/"
files = os.listdir(path)
size = len(files)
print(files[3])
print("Total samples:",size)
# Out:
# 28_0_0_20170117180555824.jpg.chip.jpg
# Total samples: 23708

# %%
images = []
ages = []
genders = []
for file in files:
    image = cv2.imread(path+file,0)
    image = cv2.resize(image,dsize=(64,64))
    image = image.reshape((image.shape[0],image.shape[1],1))
    images.append(image)
    split_var = file.split('_')
    ages.append(split_var[0])
    genders.append(int(split_var[1]))
    
x_ages = list(set(ages))
y_ages = [ages.count(i) for i in x_ages]
plt.figure(figsize=(90, 40))
plt.plot(x_ages,y_ages, color='red', linewidth=8)
plt.bar(x_ages,y_ages, color='yellow')
plt.xlabel('x_ages')
plt.ylabel('y_ages')
plt.title("Age Counter")
plt.show()
print("Max value:",max(ages))
print("Min value:",min(ages))
# Out:
# Max value: 99
# Min value: 1

# %%
def age_group(age):
    if age >=0 and age < 18:
        return 1
    elif age < 30:
        return 2
    elif age < 80:
        return 3
    else:
        return 4
    
def get_gender(prob):
    if prob < 0.5:
        return "Male"
    else:
        return "Female"

def display(img):
    plt.imshow(img[:,:,0])
    plt.show()
    
idx = 10
sample = images[idx]
display(sample)
print("Gender",get_gender(genders[idx]),"& Age:",ages[idx])
# Out:
# Gender Female & Age: 18

# %%
target = np.zeros((size,2),dtype='float32')
features = np.zeros((size,sample.shape[0],sample.shape[1],1),dtype = 'float32')
for i in range(size):
    target[i,0] = age_group(int(ages[i])) / 4
    target[i,1] = int(genders[i])
    features[i] = images[i]
features = features / 255
print("Shape of the images:",sample.shape)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, shuffle = True)
print("Training images numbers:",x_train.shape[0])
print("Testing images numbers:",x_test.shape[0])
# Out:
# Shape of the images: (64, 64, 1)
# Training images numbers: 18966
# Testing images numbers: 4742

# %%
inputs = Input(shape=(64,64, 1))
conv1 = Conv2D(32, kernel_size=(3, 3),activation='relu')(inputs)
conv2 = Conv2D(64, kernel_size=(3, 3),activation='relu')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv2)
conv3 = Conv2D(128, kernel_size=(3, 3),activation='relu')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv3)
x = Dropout(0.25)(pool2)
flat = Flatten()(x)
2
dropout = Dropout(0.5)
age_model = Dense(128, activation='relu')(flat)
age_model = dropout(age_model)
age_model = Dense(64, activation='relu')(age_model)
age_model = dropout(age_model)
age_model = Dense(32, activation='relu')(age_model)
age_model = dropout(age_model)
age_model = Dense(1, activation='relu')(age_model)

dropout = Dropout(0.5)
gender_model = Dense(128, activation='relu')(flat)
gender_model = dropout(gender_model)
gender_model = Dense(64, activation='relu')(gender_model)
gender_model = dropout(gender_model)
gender_model = Dense(32, activation='relu')(gender_model)
gender_model = dropout(gender_model)
gender_model = Dense(16, activation='relu')(gender_model)
gender_model = dropout(gender_model)
gender_model = Dense(8, activation='relu')(gender_model)
gender_model = dropout(gender_model)
gender_model = Dense(1, activation='sigmoid')(gender_model)

model = Model(inputs=inputs, outputs=[age_model,gender_model])
model.compile(optimizer = 'adam', loss =['mse','binary_crossentropy'],metrics=['accuracy'])

model.summary()

h = model.fit(x_train,[y_train[:,0],y_train[:,1]],validation_data=(x_test,[y_test[:,0],y_test[:,1]]),
             epochs = 25, batch_size=128, shuffle = True)
# Out:
# 2022-08-27 08:59:27.860726: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 62, 62, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 60, 60, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 30, 30, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 14, 14, 128)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 25088)        0           dropout[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          3211392     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             multiple             0           dense_4[0][0]
#                                                                  dense_5[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dropout_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          3211392     flatten[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 32)           2080        dropout_2[1][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             multiple             0           dense[0][0]
#                                                                  dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 16)           528         dropout_2[2][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dropout_1[1][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 8)            136         dropout_2[3][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            33          dropout_1[2][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            9           dropout_2[4][0]
# ==================================================================================================
# Total params: 6,536,834
# Trainable params: 6,536,834
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2022-08-27 08:59:28.510679: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/25
# 149/149 [==============================] - 167s 1s/step - loss: 0.8005 - dense_3_loss: 0.1122 - dense_9_loss: 0.6883 - dense_3_accuracy: 0.0123 - dense_9_accuracy: 0.5250 - val_loss: 0.6934 - val_dense_3_loss: 0.0333 - val_dense_9_loss: 0.6601 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.7138
# Epoch 2/25
# 149/149 [==============================] - 163s 1s/step - loss: 0.6606 - dense_3_loss: 0.0503 - dense_9_loss: 0.6104 - dense_3_accuracy: 0.0192 - dense_9_accuracy: 0.7161 - val_loss: 0.5720 - val_dense_3_loss: 0.0281 - val_dense_9_loss: 0.5439 - val_dense_3_accuracy: 0.0314 - val_dense_9_accuracy: 0.7796
# Epoch 3/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.5918 - dense_3_loss: 0.0417 - dense_9_loss: 0.5501 - dense_3_accuracy: 0.0211 - dense_9_accuracy: 0.7638 - val_loss: 0.4887 - val_dense_3_loss: 0.0257 - val_dense_9_loss: 0.4630 - val_dense_3_accuracy: 0.0335 - val_dense_9_accuracy: 0.8220
# Epoch 4/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.5352 - dense_3_loss: 0.0372 - dense_9_loss: 0.4980 - dense_3_accuracy: 0.0227 - dense_9_accuracy: 0.8006 - val_loss: 0.5035 - val_dense_3_loss: 0.0238 - val_dense_9_loss: 0.4797 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.7838
# Epoch 5/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.5057 - dense_3_loss: 0.0335 - dense_9_loss: 0.4722 - dense_3_accuracy: 0.0239 - dense_9_accuracy: 0.8121 - val_loss: 0.4241 - val_dense_3_loss: 0.0228 - val_dense_9_loss: 0.4013 - val_dense_3_accuracy: 0.0335 - val_dense_9_accuracy: 0.8385
# Epoch 6/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.4723 - dense_3_loss: 0.0292 - dense_9_loss: 0.4431 - dense_3_accuracy: 0.0248 - dense_9_accuracy: 0.8285 - val_loss: 0.4297 - val_dense_3_loss: 0.0206 - val_dense_9_loss: 0.4091 - val_dense_3_accuracy: 0.0335 - val_dense_9_accuracy: 0.8336
# Epoch 7/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.4464 - dense_3_loss: 0.0280 - dense_9_loss: 0.4184 - dense_3_accuracy: 0.0254 - dense_9_accuracy: 0.8366 - val_loss: 0.3770 - val_dense_3_loss: 0.0205 - val_dense_9_loss: 0.3565 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8644
# Epoch 8/25
# 149/149 [==============================] - 163s 1s/step - loss: 0.4410 - dense_3_loss: 0.0262 - dense_9_loss: 0.4148 - dense_3_accuracy: 0.0255 - dense_9_accuracy: 0.8390 - val_loss: 0.3764 - val_dense_3_loss: 0.0206 - val_dense_9_loss: 0.3558 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8545
# Epoch 9/25
# 149/149 [==============================] - 163s 1s/step - loss: 0.4120 - dense_3_loss: 0.0249 - dense_9_loss: 0.3871 - dense_3_accuracy: 0.0264 - dense_9_accuracy: 0.8497 - val_loss: 0.3477 - val_dense_3_loss: 0.0204 - val_dense_9_loss: 0.3274 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8737
# Epoch 10/25
# 149/149 [==============================] - 163s 1s/step - loss: 0.4020 - dense_3_loss: 0.0243 - dense_9_loss: 0.3777 - dense_3_accuracy: 0.0266 - dense_9_accuracy: 0.8565 - val_loss: 0.3442 - val_dense_3_loss: 0.0201 - val_dense_9_loss: 0.3241 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8722
# Epoch 11/25
# 149/149 [==============================] - 163s 1s/step - loss: 0.3959 - dense_3_loss: 0.0230 - dense_9_loss: 0.3729 - dense_3_accuracy: 0.0266 - dense_9_accuracy: 0.8566 - val_loss: 0.3355 - val_dense_3_loss: 0.0191 - val_dense_9_loss: 0.3165 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8724
# Epoch 12/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.3864 - dense_3_loss: 0.0224 - dense_9_loss: 0.3640 - dense_3_accuracy: 0.0268 - dense_9_accuracy: 0.8605 - val_loss: 0.3287 - val_dense_3_loss: 0.0188 - val_dense_9_loss: 0.3099 - val_dense_3_accuracy: 0.0335 - val_dense_9_accuracy: 0.8775
# Epoch 13/25
# 149/149 [==============================] - 165s 1s/step - loss: 0.3776 - dense_3_loss: 0.0219 - dense_9_loss: 0.3557 - dense_3_accuracy: 0.0267 - dense_9_accuracy: 0.8658 - val_loss: 0.3296 - val_dense_3_loss: 0.0197 - val_dense_9_loss: 0.3099 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8741
# Epoch 14/25
# 149/149 [==============================] - 165s 1s/step - loss: 0.3627 - dense_3_loss: 0.0217 - dense_9_loss: 0.3410 - dense_3_accuracy: 0.0266 - dense_9_accuracy: 0.8669 - val_loss: 0.3268 - val_dense_3_loss: 0.0188 - val_dense_9_loss: 0.3080 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8735
# Epoch 15/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.3525 - dense_3_loss: 0.0214 - dense_9_loss: 0.3311 - dense_3_accuracy: 0.0267 - dense_9_accuracy: 0.8726 - val_loss: 0.3214 - val_dense_3_loss: 0.0200 - val_dense_9_loss: 0.3015 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8758
# Epoch 16/25
# 149/149 [==============================] - 165s 1s/step - loss: 0.3356 - dense_3_loss: 0.0207 - dense_9_loss: 0.3149 - dense_3_accuracy: 0.0267 - dense_9_accuracy: 0.8793 - val_loss: 0.3390 - val_dense_3_loss: 0.0195 - val_dense_9_loss: 0.3195 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8574
# Epoch 17/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.3450 - dense_3_loss: 0.0208 - dense_9_loss: 0.3242 - dense_3_accuracy: 0.0268 - dense_9_accuracy: 0.8736 - val_loss: 0.3381 - val_dense_3_loss: 0.0200 - val_dense_9_loss: 0.3181 - val_dense_3_accuracy: 0.0335 - val_dense_9_accuracy: 0.8600
# Epoch 18/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.3426 - dense_3_loss: 0.0207 - dense_9_loss: 0.3219 - dense_3_accuracy: 0.0268 - dense_9_accuracy: 0.8756 - val_loss: 0.3210 - val_dense_3_loss: 0.0198 - val_dense_9_loss: 0.3012 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8747
# Epoch 19/25
# 149/149 [==============================] - 163s 1s/step - loss: 0.3170 - dense_3_loss: 0.0196 - dense_9_loss: 0.2974 - dense_3_accuracy: 0.0270 - dense_9_accuracy: 0.8860 - val_loss: 0.3290 - val_dense_3_loss: 0.0183 - val_dense_9_loss: 0.3106 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8777
# Epoch 20/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.3173 - dense_3_loss: 0.0198 - dense_9_loss: 0.2976 - dense_3_accuracy: 0.0269 - dense_9_accuracy: 0.8874 - val_loss: 0.3204 - val_dense_3_loss: 0.0185 - val_dense_9_loss: 0.3018 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8766
# Epoch 21/25
# 149/149 [==============================] - 163s 1s/step - loss: 0.3109 - dense_3_loss: 0.0194 - dense_9_loss: 0.2915 - dense_3_accuracy: 0.0270 - dense_9_accuracy: 0.8891 - val_loss: 0.3412 - val_dense_3_loss: 0.0186 - val_dense_9_loss: 0.3226 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8821
# Epoch 22/25
# 149/149 [==============================] - 164s 1s/step - loss: 0.3074 - dense_3_loss: 0.0193 - dense_9_loss: 0.2881 - dense_3_accuracy: 0.0269 - dense_9_accuracy: 0.8901 - val_loss: 0.3356 - val_dense_3_loss: 0.0190 - val_dense_9_loss: 0.3167 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8838
# Epoch 23/25
# 149/149 [==============================] - 165s 1s/step - loss: 0.3021 - dense_3_loss: 0.0192 - dense_9_loss: 0.2829 - dense_3_accuracy: 0.0270 - dense_9_accuracy: 0.8924 - val_loss: 0.3498 - val_dense_3_loss: 0.0182 - val_dense_9_loss: 0.3316 - val_dense_3_accuracy: 0.0335 - val_dense_9_accuracy: 0.8832
# Epoch 24/25
# 149/149 [==============================] - 165s 1s/step - loss: 0.2927 - dense_3_loss: 0.0187 - dense_9_loss: 0.2740 - dense_3_accuracy: 0.0269 - dense_9_accuracy: 0.8981 - val_loss: 0.3251 - val_dense_3_loss: 0.0192 - val_dense_9_loss: 0.3059 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8859
# Epoch 25/25
# 149/149 [==============================] - 165s 1s/step - loss: 0.2983 - dense_3_loss: 0.0184 - dense_9_loss: 0.2799 - dense_3_accuracy: 0.0270 - dense_9_accuracy: 0.8949 - val_loss: 0.3291 - val_dense_3_loss: 0.0192 - val_dense_9_loss: 0.3100 - val_dense_3_accuracy: 0.0337 - val_dense_9_accuracy: 0.8661

# %%
model.save('data.h')

history = h
print(history.history.keys())

plt.hist(history.history['dense_9_accuracy'])
plt.hist(history.history['val_dense_9_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
val_acc = np.mean(history.history['val_dense_9_accuracy']) 
print("%s: %.2f%%" % ('val accuracy',(val_acc*100)))
# Out:
# 2022-08-27 10:07:51.766322: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# dict_keys(['loss', 'dense_3_loss', 'dense_9_loss', 'dense_3_accuracy', 'dense_9_accuracy', 'val_loss', 'val_dense_3_loss', 'val_dense_9_loss', 'val_dense_3_accuracy', 'val_dense_9_accuracy'])
# val accuracy: 85.43%

# %%
def display(img):
    plt.imshow(img[:,:,0])
    plt.show()

def age_group(age):
    if age >=0 and age < 18:
        return 1
    elif age < 30:
        return 2
    elif age < 80:
        return 3
    else:
        return 4 #unknown

def get_age(distr):
    distr = distr*4
    if distr >= 0.65 and distr <= 1.4:return "0-18"
    if distr >= 1.65 and distr <= 2.4:return "19-30"
    if distr >= 2.65 and distr <= 3.4:return "31-80"
    if distr >= 3.65 and distr <= 4.4:return "80 +"
    return "Unknown"

def get_gender(prob):
    if prob < 0.5:return "Male"
    else: return "Female"

def get_result(sample):
    sample = sample/255 
    val = model.predict( np.array([ sample ]) )
    age = get_age(val[0])
    gender = get_gender(val[1])
    print("Predicted Gender:",gender,"Predicted Age:",age)

indexes = [777,250,2345,2346]
for idx in indexes:
    sample = images[idx] 
    display(sample)
    print("Actual Gender:",get_gender(genders[idx]),"Age:",ages[idx])
    res = get_result(sample)
# Out:
# Actual Gender: Male Age: 1
# Predicted Gender: Female Predicted Age: Unknown
# Actual Gender: Female Age: 30
# Predicted Gender: Female Predicted Age: 19-30
# Actual Gender: Male Age: 80
# Predicted Gender: Male Predicted Age: 31-80
# Actual Gender: Female Age: 59
# Predicted Gender: Female Predicted Age: 31-80
